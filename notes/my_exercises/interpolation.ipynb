# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0,1, 2**10+1)

# %%
N = 5
q = linspace(x.min(), x.max(), N)

# %%
V = array([product([(x-q[j])/(q[i]-q[j]) for j in range(N) if j != i], axis=0) for i in range(N)])

# %%
V.shape
# Out:
# (5, 65)

# %%
plot(x, V.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd360e93cf8>,
#  <matplotlib.lines.Line2D at 0x7fd360e93ef0>,
#  <matplotlib.lines.Line2D at 0x7fd360e9b128>,
#  <matplotlib.lines.Line2D at 0x7fd360e9b320>,
#  <matplotlib.lines.Line2D at 0x7fd360e9b518>]

# %% [markdown]
# To understand better, N factorial example:

# %%
product(array([range(i, i+4) for i in [3,4,5]]), axis=1)
# try also with axis=0; axis identify the index of the object we are looking at
# Out:
# array([ 360,  840, 1680])

# %%
def lagrange_basis(x, q = linspace(x.min(), x.max(), 5)):
    N = len(q)
    V = array([product([(x-q[j])/(q[i]-q[j]) for j in range(N) if j != i], axis=0) for i in range(N)])
    lebesgue = sum(abs(V), axis=0)
    return (V, lebesgue)

# %%
V, lebesgue = lagrange_basis(x)

# %%
_ = plot(x, lebesgue)

# %%
for i in range(5, 30):
    V, l = lagrange_basis(x, linspace(0,1,i))
    print(l.max())
# Out:
# 2.20539474487
# 3.10625250475
# 4.54780817032
# 6.91774760139
# 10.8398131607
# 17.6972481798
# 29.8940324826
# 50.5208722669
# 85.2746310257
# 149.48701457
# 275.054292664
# 506.416518807
# 932.433501681
# 1716.26083344
# 3157.13043182
# 5803.19794466
# 10657.3976121
# 19552.4543734
# 35833.1098385
# 65595.4700707
# 119935.138697
# 219019.097777
# 399449.318149
# 727557.674143
# 1323369.60486

# %%
plot(x, V.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd360d54978>,
#  <matplotlib.lines.Line2D at 0x7fd360d54b00>,
#  <matplotlib.lines.Line2D at 0x7fd360d54cc0>,
#  <matplotlib.lines.Line2D at 0x7fd360d54e80>,
#  <matplotlib.lines.Line2D at 0x7fd360d5d080>,
#  <matplotlib.lines.Line2D at 0x7fd360d5d240>,
#  <matplotlib.lines.Line2D at 0x7fd360d5d400>,
#  <matplotlib.lines.Line2D at 0x7fd360d5d5c0>,
#  <matplotlib.lines.Line2D at 0x7fd360d5d780>,
#  <matplotlib.lines.Line2D at 0x7fd360d5d940>,
#  <matplotlib.lines.Line2D at 0x7fd36c1bcf28>,
#  <matplotlib.lines.Line2D at 0x7fd360d5dc88>,
#  <matplotlib.lines.Line2D at 0x7fd360d5de48>,
#  <matplotlib.lines.Line2D at 0x7fd360d5dfd0>,
#  <matplotlib.lines.Line2D at 0x7fd360d66208>,
#  <matplotlib.lines.Line2D at 0x7fd360d663c8>,
#  <matplotlib.lines.Line2D at 0x7fd360d66588>,
#  <matplotlib.lines.Line2D at 0x7fd360d66748>,
#  <matplotlib.lines.Line2D at 0x7fd360d66908>,
#  <matplotlib.lines.Line2D at 0x7fd360d66ac8>,
#  <matplotlib.lines.Line2D at 0x7fd360d66c88>,
#  <matplotlib.lines.Line2D at 0x7fd360d66e48>,
#  <matplotlib.lines.Line2D at 0x7fd360d66fd0>,
#  <matplotlib.lines.Line2D at 0x7fd360d6b208>,
#  <matplotlib.lines.Line2D at 0x7fd360d6b3c8>,
#  <matplotlib.lines.Line2D at 0x7fd360d6b588>,
#  <matplotlib.lines.Line2D at 0x7fd360d6b748>,
#  <matplotlib.lines.Line2D at 0x7fd360d6b908>,
#  <matplotlib.lines.Line2D at 0x7fd360d6bac8>]

# %%
N = 50
theta = arange(N)
def cheby(N):
    return .5*(1-cos(pi*(2*arange(N)+1)/(2*N)))

q = cheby(N)
print()
V,l= lagrange_basis(x,q)

_ = plot(x, V.T)

# %%
plot(x, l)

# %%
for i in arange(5, 500):
    V,l = lagrange_basis(x, cheby(i))
    print(l.max())
# Out:
# 1.988854382
# 2.10439768265
# 2.20221455521
# 2.28701606846
# 2.36185678777
# 2.42882948238
# 2.48943037688
# 2.54476611865
# 2.59567818079
# 2.6428212935
# 2.68671488157
# 2.72777793642
# 2.76635333589
# 2.80272522418
# 2.83713169974
# 2.86977425303
# 2.90082490445
# 2.93043168361
# 2.95872289186
# 2.98581045847
# 3.01179261235
# 3.03675603012
# 3.06077757917
# 3.08392574385
# 3.10626180168
# 3.12784080017
# 3.14871237367
# 3.16892143048
# 3.18850873446
# 3.20751139966
# 3.22596331346
# 3.24389550002
# 3.261336434
# 3.27831231244
# 3.29484729138
# 3.31096369247
# 3.32668218414
# 3.3420219409
# 3.35700078396
# 3.37163530558
# 3.38594097961
# 3.39993225973
# 3.41362266722
# 3.42702486949
# 3.44015075046
# 3.45301147386
# 3.46561754032
# 3.4779788388
# 3.49010469325
# 3.50200390481
# 3.51368479019
# 3.52515521658
# 3.53642263347
# 3.54749410171
# 3.55837632008
# 3.56907564962
# 3.57959813598
# 3.5899495299
# 3.60013530611
# 3.61016068071
# 3.6200306272
# 3.62974989128
# 3.63932300459
# 3.64875429737
# 3.65804791023
# 3.66720780503
# 3.67623777508
# 3.68514145452
# 3.69392232711
# 3.70258373444
# 3.71112888354
# 3.719560854
# 3.72788260467
# 3.73609697984
# 3.74420671513
# 3.75221444291
# 3.76012269748
# 3.76793391983
# 3.7756504622
# 3.78327459231
# 3.79080849741
# 3.79825428796
# 3.80561400125
# 3.81288960472
# 3.82008299911
# 3.82719602147
# 3.83423044793
# 3.84118799641
# 3.8480703291
# 3.85487905485
# 3.86161573148
# 3.86828186782
# 3.87487892584
# 3.88140832248
# 3.88787143158
# 3.89426958551
# 3.9006040769
# 3.90687616017
# 3.91308705301
# 3.91923793782
# 3.92532996308
# 3.93136424458
# 3.9373418667
# 3.94326388355
# 3.9491313201
# 3.95494517324
# 3.96070641279
# 3.96641598248
# 3.97207480087
# 3.97768376225
# 3.98324373747
# 3.98875557477
# 3.99422010053
# 3.99963812005
# 4.00501041825
# 4.01033776031
# 4.01562089239
# 4.02086054222
# 4.02605741971
# 4.03121221752
# 4.03632561161
# 4.04139826181
# 4.04643081228
# 4.05142389203
# 4.05637811537
# 4.06129408242
# 4.06617237946
# 4.07101357941
# 4.07581824223
# 4.08058691528
# 4.08532013373
# 4.09001842087
# 4.09468228854
# 4.09931223737
# 4.10390875713
# 4.10847232713
# 4.11300341637
# 4.11750248396
# 4.12196997931
# 4.12640634245
# 4.13081200428
# 4.1351873868
# 4.13953290337
# 4.14384895896
# 4.14813595035
# 4.15239426634
# 4.15662428802
# 4.16082638889
# 4.16500093512
# 4.16914828575
# 4.17326879279
# 4.17736280153
# 4.18143065056
# 4.18547267211
# 4.18948919205
# 4.19348053015
# 4.19744700021
# 4.20138891019
# 4.20530656234
# 4.20920025343
# 4.21307027476
# 4.21691691236
# 4.22074044713
# 4.2245411549
# 4.22831930663
# 4.23207516848
# 4.23580900187
# 4.23952106374
# 4.24321160648
# 4.24688087816
# 4.25052912256
# 4.25415657933
# 4.25776348399
# 4.26135006815
# 4.26491655945
# 4.26846318179
# 4.27199015532
# 4.27549769655
# 4.27898601844
# 4.28245533046
# 4.28590583869
# 4.28933774584
# 4.29275125142
# 4.29614655168
# 4.2995238398
# 4.30288330586
# 4.306225137
# 4.30954951735
# 4.31285662825
# 4.31614664819
# 4.31941975291
# 4.32267611546
# 4.32591590622
# 4.32913929304
# 4.33234644116
# 4.33553751341
# 4.33871267012
# 4.34187206929
# 4.34501586652
# 4.34814421513
# 4.35125726627
# 4.35435516876
# 4.35743806933
# 4.36050611259
# 4.36355944106
# 4.36659819522
# 4.36962251349
# 4.37263253245
# 4.37562838663
# 4.37861020876
# 4.38157812963
# 4.38453227829
# 4.38747278193
# 4.39039976607
# 4.39331335442
# 4.39621366906
# 4.39910083038
# 4.40197495713
# 4.4048361665
# 4.40768457403
# 4.41052029384
# 4.41334343838
# 4.41615411877
# 4.41895244453
# 4.42173852382
# 4.42451246335
# 4.42727436845
# 4.43002434311
# 4.43276248996
# 4.43548891027
# 4.4382037041
# 4.44090697014
# 4.44359880594
# 4.44627930767
# 4.44894857044
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-0a215c8e5ba3> in <module>()
#       1 for i in arange(5, 500):
# ----> 2     V,l = lagrange_basis(x, cheby(i))
#       3     print(l.max())
#
# <ipython-input-33-6474aa031c4a> in lagrange_basis(x, q)
#       1 def lagrange_basis(x, q = linspace(x.min(), x.max(), 5)):
#       2     N = len(q)
# ----> 3     V = array([product([(x-q[j])/(q[i]-q[j]) for j in range(N) if j != i], axis=0) for i in range(N)])
#       4     lebesgue = sum(abs(V), axis=0)
#       5     return (V, lebesgue)
#
# <ipython-input-33-6474aa031c4a> in <listcomp>(.0)
#       1 def lagrange_basis(x, q = linspace(x.min(), x.max(), 5)):
#       2     N = len(q)
# ----> 3     V = array([product([(x-q[j])/(q[i]-q[j]) for j in range(N) if j != i], axis=0) for i in range(N)])
#       4     lebesgue = sum(abs(V), axis=0)
#       5     return (V, lebesgue)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in product(a, axis, dtype, out, keepdims)
#    1847     if keepdims is not np._NoValue:
#    1848         kwargs['keepdims'] = keepdims
# -> 1849     return um.multiply.reduce(a, axis=axis, dtype=dtype, out=out, **kwargs)
#    1850
#    1851
#
# KeyboardInterrupt:

# %% [markdown]
# Multiple dims, alternative to broadcasting

# %%
x = linspace(0,1,2**6+1)
y = linspace(0,1,2**7+1)

Nx = 5
Ny = 6

Vx, lx = lagrange_basis(x, cheby(Nx))
Vy, ly = lagrange_basis(y, cheby(Ny))

# %%
Vx.shape
# Out:
# (5, 65)

# %%
Vy.shape
# Out:
# (6, 129)

# %%
V = einsum('ij, kl -> ikjl', Vy, Vx)

# %%
X = einsum('i,j -> ij', y,x)

# %%
V[0][0].shape
# Out:
# (129, 65)

# %%
X.shape
# Out:
# (129, 65)

# %%
X, Y = meshgrid(x,y)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')

#ax.plot_surface(X,Y,V[0][0])
ax.plot_surface(X,Y,V[2][1],cmap=cm.coolwarm)

# %% [markdown]
# Look at how V is constructed. f(x) and g(y) are evaluated only once, then the result is broadcasted by ndarrays.

# %%
def runge(x,y):
    return 1/(1+10*(x-.5)**2+10*(y-.5)**2)

# %%
R = runge(X,Y)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

#ax.plot_surface(X,Y,V[0][0])
ax.plot_surface(X,Y,R,cmap=cm.coolwarm)

# %%
Qx, Qy = meshgrid(cheby(Nx), cheby(Ny))

# %%
Rq = runge(Qx, Qy)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

#ax.plot_surface(X,Y,V[0][0])
ax.plot_surface(Qx,Qy,Rq,cmap=cm.coolwarm)

# %%
P = einsum('ij, ijkl', Rq, V)


fig = plt.figure()
ax = fig.gca(projection='3d')

#ax.plot_surface(X,Y,V[0][0])
ax.plot_surface(X,Y,P,cmap=cm.coolwarm)
